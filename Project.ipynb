# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
# %matplotlib inline



pd.set_option("display.max_rows", 60, "display.max_columns", 60)

# %%
fifa = pd.read_csv("data.csv", index_col = 0)
df= fifa
df.head(5)
# Out:
#   Nationality  Overall  Potential                 Club    Value   Wage  \
# 0   Argentina       94         94         FC Barcelona  €110.5M  €565K
# 1    Portugal       94         94             Juventus     €77M  €405K
# 2      Brazil       92         93  Paris Saint-Germain  €118.5M  €290K
# 3       Spain       91         93    Manchester United     €72M  €260K
# 4     Belgium       91         92      Manchester City    €102M  €355K
#
#    Special  International Reputation  Skill Moves Position  Crossing  \
# 0     2202                       5.0          4.0       RF      84.0
# 1     2228                       5.0          5.0       ST      84.0
# 2     2143                       5.0          5.0       LW      79.0
# 3     1471                       4.0          1.0       GK      17.0
# 4     2281                       4.0          4.0      RCM      93.0
#
#    Finishing  HeadingAccuracy  ShortPassing  Volleys  Dribbling  Curve  \
# ...

# %%
df.shape
# Out:
# (18207, 37)

# %%
df = df.drop(columns = ['Name', 'Photo', 'Flag', 'Club Logo', 'Body Type', 'Real Face', 'Jersey Number', 'Preferred Foot',
                        'Joined', 'Work Rate', 'Loaned From', 'Contract Valid Until', 'Height', 'Weight', 'LS', 'ST', 
                        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 
                        'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Release Clause', 'Age', 'Weak Foot', 
                        'Jumping', 'Strength', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'])
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-dadc3fdda09c> in <module>
#       3                         'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB',
#       4                         'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'Release Clause', 'Age', 'Weak Foot',
# ----> 5                         'Jumping', 'Strength', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'])
#       6 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.shape
# Out:
# (18207, 38)

# %%
df.Wage = df['Wage'].str.replace('€', '')
df.Value = df['Value'].str.replace('€', '')
df
# Out:
#            ID Nationality  Overall  Potential                 Club   Value  \
# 0      158023   Argentina       94         94         FC Barcelona  110.5M
# 1       20801    Portugal       94         94             Juventus     77M
# 2      190871      Brazil       92         93  Paris Saint-Germain  118.5M
# 3      193080       Spain       91         93    Manchester United     72M
# 4      192985     Belgium       91         92      Manchester City    102M
# ...       ...         ...      ...        ...                  ...     ...
# 18202  238813     England       47         65      Crewe Alexandra     60K
# 18203  243165      Sweden       47         63       Trelleborgs FF     60K
# 18204  241638     England       47         67     Cambridge United     60K
# 18205  246268     England       47         66      Tranmere Rovers     60K
# 18206  246269     England       46         66      Tranmere Rovers     60K
#
# ...

# %%
df.Value = (df.Value.replace(r'[KM]+', '', regex=True).astype(float) *  df.Value.str.extract(r'[\d\.]+([KM]+)', expand=False)
           .fillna(1)
          .replace(['K','M'], [10**3, 10**6]).astype(int))
df.Wage = (df.Wage.replace(r'[KM]+', '', regex=True).astype(float) *  df.Wage.str.extract(r'[\d\.]+([KM]+)', expand=False)
           .fillna(1)
          .replace(['K','M'], [10**3, 10**6]).astype(int))
df
# Out:
#            ID Nationality  Overall  Potential                 Club  \
# 0      158023   Argentina       94         94         FC Barcelona
# 1       20801    Portugal       94         94             Juventus
# 2      190871      Brazil       92         93  Paris Saint-Germain
# 3      193080       Spain       91         93    Manchester United
# 4      192985     Belgium       91         92      Manchester City
# ...       ...         ...      ...        ...                  ...
# 18202  238813     England       47         65      Crewe Alexandra
# 18203  243165      Sweden       47         63       Trelleborgs FF
# 18204  241638     England       47         67     Cambridge United
# 18205  246268     England       47         66      Tranmere Rovers
# 18206  246269     England       46         66      Tranmere Rovers
#
#              Value      Wage  Special  International Reputation  Skill Moves  \
# 0      110500000.0  565000.0     2202                       5.0          4.0
# ...

# %%
print(df[df.Position == 'GK'])
# Out:
#            ID Nationality  Overall  Potential               Club       Value  \
# 3      193080       Spain       91         93  Manchester United  72000000.0
# 9      200389    Slovenia       90         93    Atlético Madrid  68000000.0
# 18     192448     Germany       89         92       FC Barcelona  58000000.0
# 19     192119     Belgium       89         90        Real Madrid  53500000.0
# 22     167495     Germany       89         89  FC Bayern München  38000000.0
# ...       ...         ...      ...        ...                ...         ...
# 18178  243158      Sweden       48         65         Dalkurd FF     50000.0
# 18180  221669    Scotland       48         58   St. Johnstone FC     40000.0
# 18183   53748     England       48         48   Cambridge United         0.0
# 18194  245862       Italy       47         65              Lecce     50000.0
# 18198  242844     England       47         70      Burton Albion     60000.0
#
# ...

# %%
df.drop(df[df.Position == 'GK'].index, axis = 0, inplace = True)

# %%
df.reset_index(drop = True)
# Out:
#            ID Nationality  Overall  Potential                 Club  \
# 0      158023   Argentina       94         94         FC Barcelona
# 1       20801    Portugal       94         94             Juventus
# 2      190871      Brazil       92         93  Paris Saint-Germain
# 3      192985     Belgium       91         92      Manchester City
# 4      183277     Belgium       91         91              Chelsea
# ...       ...         ...      ...        ...                  ...
# 16177  238813     England       47         65      Crewe Alexandra
# 16178  243165      Sweden       47         63       Trelleborgs FF
# 16179  241638     England       47         67     Cambridge United
# 16180  246268     England       47         66      Tranmere Rovers
# 16181  246269     England       46         66      Tranmere Rovers
#
#              Value      Wage  Special  International Reputation  Skill Moves  \
# 0      110500000.0  565000.0     2202                       5.0          4.0
# ...

# %%
df.describe()
# Out:
#                   ID       Overall     Potential         Value           Wage  \
# count   16182.000000  16182.000000  16182.000000  1.618200e+04   16182.000000
# mean   215101.849833     66.443332     71.496045  2.513921e+06   10097.639352
# std     28580.889885      6.790578      6.080010  5.702692e+06   22546.890252
# min        16.000000     46.000000     48.000000  0.000000e+00       0.000000
# 25%    200925.750000     62.000000     67.000000  3.500000e+05    1000.000000
# 50%    222077.500000     66.000000     71.000000  7.250000e+05    3000.000000
# 75%    236665.500000     71.000000     75.000000  2.200000e+06    9000.000000
# max    246620.000000     94.000000     95.000000  1.185000e+08  565000.000000
#
#             Special  International Reputation   Skill Moves      Crossing  \
# count  16182.000000              16134.000000  16134.000000  16134.000000
# mean    1666.837227                  1.115408      2.532168     54.186934
# ...

# %%
scaler = MinMaxScaler()
print(scaler.fit(df[['Wage', 'Value']]))
df[['Wage', 'Value']] = scaler.transform(df[['Wage', 'Value']])
df
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))
#            ID Nationality  Overall  Potential                 Club     Value  \
# 0      158023   Argentina       94         94         FC Barcelona  0.932489
# 1       20801    Portugal       94         94             Juventus  0.649789
# 2      190871      Brazil       92         93  Paris Saint-Germain  1.000000
# 4      192985     Belgium       91         92      Manchester City  0.860759
# 5      183277     Belgium       91         91              Chelsea  0.784810
# ...       ...         ...      ...        ...                  ...       ...
# 18202  238813     England       47         65      Crewe Alexandra  0.000506
# 18203  243165      Sweden       47         63       Trelleborgs FF  0.000506
# 18204  241638     England       47         67     Cambridge United  0.000506
# 18205  246268     England       47         66      Tranmere Rovers  0.000506
# 18206  246269     England       46         66      Tranmere Rovers  0.000506
# ...

# %%
fig, ax = plt.subplots(figsize=(16,16)) 
sns.heatmap(data.corr(), annot=True, ax=ax, cmap='BrBG').set(
    title = 'Feature Correlation', xlabel = 'Columns', ylabel = 'Columns')
plt.show()



df.corr()
# Out:
#                                 ID   Overall  Potential     Value      Wage  \
# ID                        1.000000 -0.425584   0.052434 -0.151829 -0.213702
# Overall                  -0.425584  1.000000   0.650483  0.634844  0.575823
# Potential                 0.052434  0.650483   1.000000  0.577105  0.485331
# Value                    -0.151829  0.634844   0.577105  1.000000  0.858255
# Wage                     -0.213702  0.575823   0.485331  0.858255  1.000000
# Special                  -0.414207  0.795604   0.465838  0.493147  0.451972
# International Reputation -0.365039  0.501952   0.368039  0.656947  0.668056
# Skill Moves              -0.151925  0.505436   0.414767  0.381262  0.313047
# Crossing                 -0.276913  0.496814   0.273458  0.305229  0.284884
# Finishing                -0.169775  0.373000   0.253649  0.293694  0.244920
# HeadingAccuracy          -0.288248  0.467296   0.225067  0.236776  0.248096
# ...

# %%
# Out:
#        Unnamed: 0      ID            Name  Age  \
# 13236       13236  177971      J. McNulty   33
# 13237       13237  195380      J. Barrera   29
# 13238       13238  139317        J. Stead   35
# 13239       13239  240437     A. Semprini   20
# 13240       13240  209462      R. Bingham   24
# 13241       13241  219702    K. Dankowski   21
# 13242       13242  225590       I. Colman   23
# 13243       13243  233782       M. Feeney   19
# 13244       13244  239158        R. Minor   30
# 13245       13245  242998          Klauss   21
# 13246       13246  244022      I. Sissoko   22
# 13247       13247  189238         F. Hart   28
# 13248       13248  211511   L. McCullough   24
# 13249       13249  224055       Li Yunqiu   27
# 13250       13250  244535       F. Garcia   29
# 13251       13251  134968    R. Haemhouts   34
# 13252       13252  225336       E. Binaku   22
# 13253       13253  171320       G. Miller   31
# 13254       13254  246328      A. Aidonis   17
# ...

# %%
# Out:
# (18159, 89)

# %%
df.shape
# Out:
# (18207, 89)

# %%
df.Wage.head(10)
# Out:
# 0    €565K
# 1    €405K
# 2    €290K
# 3    €260K
# 4    €355K
# 5    €340K
# 6    €420K
# 7    €455K
# 8    €380K
# 9     €94K
# Name: Wage, dtype: object

# %%
df.Value.head(10)
# Out:
# 0    €110.5M
# 1       €77M
# 2    €118.5M
# 3       €72M
# 4      €102M
# 5       €93M
# 6       €67M
# 7       €80M
# 8       €51M
# 9       €68M
# Name: Value, dtype: object

# %%
conv = (df['Wage'].replace( '[K\€,)]','', regex=True )
               .replace( '[(]','-',   regex=True ).astype(float))

# %%
Wage = df['Wage'].str.replace('€', '')
Wage.head(10)
# Out:
# 0    565K
# 1    405K
# 2    290K
# 3    260K
# 4    355K
# 5    340K
# 6    420K
# 7    455K
# 8    380K
# 9     94K
# Name: Wage, dtype: object

# %%
Value = df['Value'].str.replace('€', '')
Value.head(10)
# Out:
# 0    110.5M
# 1       77M
# 2    118.5M
# 3       72M
# 4      102M
# 5       93M
# 6       67M
# 7       80M
# 8       51M
# 9       68M
# Name: Value, dtype: object

# %%
dfg = df.groupby(by = 'Nationality')
dfg.count()
# Out:
# dtype('int32')
